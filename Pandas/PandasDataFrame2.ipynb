# %% [markdown]
# ### More Important Functions

# %%
# value_counts
# sort_values
# rank
# sort index
# set index
# rename index -> rename
# reset index
# unique & nunique
# isnull/notnull/hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %%
import numpy as np
import pandas as pd

# %%
a = pd.Series([1,1,1,2,2,3])
a.value_counts()
# Out:
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
# value counts(series and dataframe)  -> frequency count karke batata hai , har unique item ka 

marks = pd.DataFrame([
    [100,90,7],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
], columns=['iq','marks','package'])

marks
# Out:
#     iq  marks  package
# 0  100     90        7
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.value_counts() # kitne rows repeat hue hai or un rows ke repeat ka frequency kya hai or u can say pure row ka frequency count batata hai
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  90     7          1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl = pd.read_csv(r'C:\Users\HP\OneDrive\Documents\Desktop\python-libraries\Data\ipl-matches.csv')
ipl.sample()
# Out:
#           ID    City        Date Season MatchNumber                Team1  \
# 132  1254059  Mumbai  2021-04-10   2021           2  Chennai Super Kings
#
#               Team2                     Venue      TossWinner TossDecision  \
# 132  Delhi Capitals  Wankhede Stadium, Mumbai  Delhi Capitals        field
#
#     SuperOver     WinningTeam    WonBy  Margin method Player_of_Match  \
# 132         N  Delhi Capitals  Wickets     7.0    NaN        S Dhawan
#
#                                           Team1Players  \
# 132  ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'SK R...
#
#                                           Team2Players       Umpire1  \
# 132  ['PP Shaw', 'S Dhawan', 'RR Pant', 'MP Stoinis...  AK Chaudhary
#
#        Umpire2
# 132  VK Sharma

# %%
# find which player has won most potm -> in finals and qualifiers
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# Toss decision plot 
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played -> u can add two series if index value is matching
(ipl['Team1'].value_counts() + ipl['Team1'].value_counts()).sort_values(ascending=False)
# Out:
# Team1
# Royal Challengers Bangalore    252
# Mumbai Indians                 224
# Chennai Super Kings            222
# Kolkata Knight Riders          210
# Kings XI Punjab                184
# Rajasthan Royals               178
# Delhi Daredevils               170
# Sunrisers Hyderabad            138
# Deccan Chargers                 78
# Delhi Capitals                  58
# Pune Warriors                   46
# Punjab Kings                    36
# Gujarat Lions                   32
# Lucknow Super Giants            16
# Gujarat Titans                  14
# Rising Pune Supergiant          14
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
# sort_values(series and dataframe) -> ascending -> na_position -> inplace -> multilple cols
x = pd.Series([12,14,1,56,89])
x
# Out:
# 0    12
# 1    14
# 2     1
# 3    56
# 4    89
# dtype: int64

# %%
x.sort_values(ascending=False)
# Out:
# 4    89
# 3    56
# 1    14
# 0    12
# 2     1
# dtype: int64

# %%
movies = pd.read_csv(r'C:\Users\HP\OneDrive\Documents\Desktop\python-libraries\Data\movies.csv')

# %%
movies.sort_values('title_x')
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]
    }
)
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name',na_position='first', inplace=True) # missing values ko last mai le jata hai

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students.sort_values('name',na_position='first')
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
#  sorting on  2 col
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rank (series) ->  genrate a rank on the basis of a single  column

# %%
batsman = pd.read_csv(r'C:\Users\HP\OneDrive\Documents\Desktop\python-libraries\Data\batsman_runs_ipl.csv')

# %%
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['batting_rank']= batsman['batsman_run'].rank(ascending=False)

# %%
batsman.sort_values('batting_rank')
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 600    Yash Dayal            0         594.0
# 595    YA Abdulla            0         594.0
# 57         AS Roy            0         594.0
# 63   Abdur Razzak            0         594.0
# 65     Akash Deep            0         594.0
#
# [605 rows x 3 columns]

# %%
# sort_index(series and dataframe) -> index ko sort kar deta hai

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

# %%
marks = pd.Series(marks)

# %%
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks.sort_index()
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# set_index(dataframe) ->  data frame ka kese col ko index banana ho toh

# %%
batsman.set_index('batter',inplace=True)

# %%
batsman
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# reset_index(Series + dataframe) -> drop parameter , it is apposite to set index

# %%
batsman
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
batsman.reset_index()
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
# how to replace existing index without loosing
batsman.reset_index().set_index('batting_rank') # existing index ko hatana hai without usko lose kiye
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
# series to dataframe using reset_index
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks.reset_index()
# Out:
#      index    0
# 0    maths   67
# 1  english   57
# 2  science   89
# 3    hindi  100

# %%
#  rename(dataframe) ->index -> col ka name change karta hai and index ka name bhe change kar deta hai

# %%
movies.set_index('title_x',inplace=True)

# %%
movies.rename(columns={'imdb_id':'imbd'},inplace=True)

# %%
movies.head(1)
# Out:
#                                imbd  \
# title_x
# Uri: The Surgical Strike  tt8291224
#
#                                                                 poster_path  \
# title_x
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                                            title_y            original_title  \
# title_x
# Uri: The Surgical Strike  Uri: The Surgical Strike  Uri: The Surgical Strike
#
#                           is_adult  year_of_release runtime            genres  \
# title_x
# Uri: The Surgical Strike         0             2019     138  Action|Drama|War
#
#                           imdb_rating  imdb_votes  \
# title_x
# Uri: The Surgical Strike          8.4       35112
#
#                                                                       story  \
# title_x
# ...

# %%
movies.rename(index={'Uri: The Surgical Strike':'Uri'},inplace=True)

# %%
# unique(series) -> series mai se unique value filter karta hai

# %%
temp = pd.Series([1,1,1,2,3,4,np.nan])

# %%
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan])

# %%
len(ipl['Season'].unique())
# Out:
# 15

# %%
# nunique(series + dataframe) -> does not count nan -> dropna parameter
ipl['Season'].nunique() # unique value ka count deta hai
# Out:
# 15

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
#  isnull (series+dataframe) -> tells ki kese col mai mai missing value hai ya ni 
students['name'][students['name'].isnull()] # -> har row ke pass jake poochat hai ki tum missing value ho ya ni ho toh true ni toh false
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
# notnull(series+dataframe) -> tells ki kese col mai mai missing value hai ya ni 
students['name'][students['name'].notnull()] # opposite to isnull
# Out:
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
# hasnans(series) -> tells ki kese col mai mai missing value hai ya ni 
students['name'].hasnans
# Out:
# True

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 3   True     True    True   True     True
# 5   True    False   False  False    False
# 7   True     True   False  False    False
# 9   True    False    True   True     True
# 8  False     True   False  False     True
# 1  False    False   False  False    False
# 4  False     True   False  False    False
# 0  False    False   False  False    False
# 6  False    False   False  False    False
# 2  False    False   False  False    False

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 3  False    False   False  False    False
# 5  False     True    True   True     True
# 7  False    False    True   True     True
# 9  False     True   False  False    False
# 8   True    False    True   True    False
# 1   True     True    True   True     True
# 4   True    False    True   True     True
# 0   True     True    True   True     True
# 6   True     True    True   True     True
# 2   True     True    True   True     True

# %%
# dropna(series+dataframe) -> missing value ko hata deta hai completely
students['name'].dropna(how='any') # agr pure row mai ek bhe value missing hai to pure row ko hata deta hai
# Out:
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
students.dropna()
# Out:
#       name college branch  cgpa  package
# 1    ankit     iit     it  8.25      5.0
# 0   nitish     bit    eee  6.66      4.0
# 6  rishabh    ssit    civ  7.40      8.0
# 2   rupesh     vit    cse  6.41      6.0

# %%
students['name'].dropna(how='all') # woh row hi remove hoge jisme sare value missing ho
# Out:
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
#  particular col ya multiple col ke basis pr bhe remove kar sakte hai
students.dropna(subset=['name'])
# Out:
#          name college branch  cgpa  package
# 8      aditya     NaN    bio  7.40      NaN
# 1       ankit     iit     it  8.25      5.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 0      nitish     bit    eee  6.66      4.0
# 6     rishabh    ssit    civ  7.40      8.0
# 2      rupesh     vit    cse  6.41      6.0

# %%
# sab row ko hata dega jha p name mai missing value hai ya college mai missing value hai
students.dropna(subset=['name','college'])
# Out:
#       name college branch  cgpa  package
# 1    ankit     iit     it  8.25      5.0
# 0   nitish     bit    eee  6.66      4.0
# 6  rishabh    ssit    civ  7.40      8.0
# 2   rupesh     vit    cse  6.41      6.0

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
# fillna(series+dataframe) -> missing value ko fill kar deta hai

# %%
students['name'].fillna('unknown').hasnans
# Out:
# False

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students.fillna(0)
# Out:
#          name college branch   cgpa  package
# 3           0       0      0   0.00      0.0
# 5           0    vlsi     ce   9.00      7.0
# 7           0       0    cse  10.00      9.0
# 9           0     git      0   0.00      0.0
# 8      aditya       0    bio   7.40      0.0
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay       0     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students['package'].fillna(students['package'].mean())
# Out:
# 3    6.428571
# 5    7.000000
# 7    9.000000
# 9    6.428571
# 8    6.428571
# 1    5.000000
# 4    6.000000
# 0    4.000000
# 6    8.000000
# 2    6.000000
# Name: package, dtype: float64

# %%
students['name'].fillna(method='ffill')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9180\538422019.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['name'].fillna(method='ffill')
# 3           NaN
# 5           NaN
# 7           NaN
# 9           NaN
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
#  drop_duplicates(series+dataframe) -> like duplicated -> kitne rows duplicated hai

# %%
marks
# Out:
#     iq  marks  package
# 0  100     90        7
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.duplicated().sum() # total kitne no of row duplicated hai
# Out:
# np.int64(1)

# %%
#  drop duplicate , duplicate row ko hata deta hai

# %%
temp = pd.Series([1,1,1,1,2,3])

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# 5    3
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 4    2
# 5    3
# dtype: int64

# %%
marks
# Out:
#     iq  marks  package
# 0  100     90        7
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.drop_duplicates(keep='last')
# Out:
#     iq  marks  package
# 0  100     90        7
# 1   90     70        7
# 2  120    100       14
# 4   80     70       14

# %%
# find the last match played by virat kohli in Delhi

# %%
ipl.sample()
# Out:
#           ID    City        Date Season MatchNumber                Team1  \
# 122  1254069  Mumbai  2021-04-19   2021          12  Chennai Super Kings
#
#                 Team2                     Venue        TossWinner  \
# 122  Rajasthan Royals  Wankhede Stadium, Mumbai  Rajasthan Royals
#
#     TossDecision SuperOver          WinningTeam WonBy  Margin method  \
# 122        field         N  Chennai Super Kings  Runs    45.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 122          MM Ali  ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'SK R...
#
#                                           Team2Players     Umpire1    Umpire2
# 122  ['JC Buttler', 'M Vohra', 'SV Samson', 'S Dube...  PR Reiffel  VK Sharma

# %%
c = ipl['City'] == 'Delhi'
c.sum()
# Out:
# np.int64(78)

# %%
ipl.sample()
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 26  1304094  Navi Mumbai  2022-05-03   2022          48  Gujarat Titans
#
#            Team2                               Venue      TossWinner  \
# 26  Punjab Kings  Dr DY Patil Sports Academy, Mumbai  Gujarat Titans
#
#    TossDecision SuperOver   WinningTeam    WonBy  Margin method  \
# 26          bat         N  Punjab Kings  Wickets     8.0    NaN
#
#    Player_of_Match                                       Team1Players  \
# 26        K Rabada  ['WP Saha', 'Shubman Gill', 'B Sai Sudharsan',...
#
#                                          Team2Players   Umpire1    Umpire2
# 26  ['JM Bairstow', 'S Dhawan', 'PBB Rajapaksa', '...  R Pandit  VK Sharma

# %%
a = ipl['Team1Players'].str.contains('V Kohli')
a.sum()
# Out:
# np.int64(124)

# %%
b = ipl['Team2Players'].str.contains('V Kohli')
b.sum()
# Out:
# np.int64(98)

# %%
d = a+b

# %%
ipl[(d & c)]['Season']
# Out:
# 208       2019
# 269       2018
# 318       2017
# 467       2015
# 571       2013
# 638       2012
# 746       2011
# 801    2009/10
# 933    2007/08
# Name: Season, dtype: object

# %%
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']

# %%
def did_kohli_play(players_list):
    return 'V Kohli' in players_list

# %%
ipl['did_kholi_play']=ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kholi_play'] == True)].drop_duplicates(subset=['City','did_kholi_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kholi_play
# 208           True
#
# [1 rows x 22 columns]

# %%
# drop(series + dataframe) -> row ya col ko drop karta hai
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# 5    3
# dtype: int64

# %%
temp.drop(index=[0,5])
# Out:
# 1    1
# 2    1
# 3    1
# 4    2
# dtype: int64

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students.drop(columns=['branch','cgpa'])
# Out:
#          name college  package
# 3         NaN     NaN      NaN
# 5         NaN    vlsi      7.0
# 7         NaN     NaN      9.0
# 9         NaN     git      NaN
# 8      aditya     NaN      NaN
# 1       ankit     iit      5.0
# 4  mrityunjay     NaN      6.0
# 0      nitish     bit      4.0
# 6     rishabh    ssit      8.0
# 2      rupesh     vit      6.0

# %%
students.drop(index=[0,8])
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
# apply(series+dataframe)

# %%
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# 5    3
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.367879
# 1    1.367879
# 2    1.367879
# 3    1.367879
# 4    1.135335
# 5    1.049787
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
      '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
      '2nd point' : [(-3,4),(0,0),(2,2),(10,10),(1,1)]  
    }
)

# %%
points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def distance(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']

    return  ((pt_A[0]-pt_B[0])**2 + (pt_A[1]-pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(distance,axis=1)

# %%
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
